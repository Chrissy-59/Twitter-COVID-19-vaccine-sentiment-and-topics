# %%
import pandas as pd

# %%
df1 = pd.read_excel('2020_1201to202.xlsx')
df2 = pd.read_csv('2021_215to220.csv')
df3 = pd.read_csv('2021_221to223.csv')
df4 = pd.read_csv('2021_224to228.csv')
df5 = pd.read_csv('2021_301to308.csv')
df6 = pd.read_csv('2021_309to312.csv')
df7 = pd.read_csv('vaccination_all_tweets.csv')

# %%
df = pd.concat([df1,df2,df3,df4,df5,df6,df7])

# %%
df = df.drop(columns=['Unnamed: 0','id','retweets','favorites'])

# %%
df
# Out:
#                                                user_name        user_location  \
# 0                                                AJ Love          Seattle, WA
# 1                                       Darkly Dangerous         Vermont, USA
# 2                                  Thailand Medical News    Bangkok, Thailand
# 3      Ashwani Kumar | ‡§Ö‡§∂‡•ç‡§µ‡§®‡•Ä ‡§ï‡•Å‡§Æ‡§...     New Delhi, India
# 4      Ashwani Kumar | ‡§Ö‡§∂‡•ç‡§µ‡§®‡•Ä ‡§ï‡•Å‡§Æ‡§...     New Delhi, India
# ...                                                  ...                  ...
# 28249                                              ILKHA              Türkiye
# 28250                                               صادق  South East, England
# 28251                                  Nicola Facciolini             L'Aquila
# 28252          #IamJulianAssange|#LetSyriaBreathe|#Yemen                    🌐
# 28253                                           Ferguson                  NaN
#
# ...

# %%
df = df.drop_duplicates(subset=['text'])

# %%
f_data['date'] = pd.to_datetime(f_data['date'])
# Out:
# <ipython-input-40-29bf853a56de>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_data['date'] = pd.to_datetime(f_data['date'])

# %%
f_data = f_data.sort_values(by='date')

# %%
f_data['date'] = f_data['date'].dt.date

# %%
f_data
# Out:
#                          user_name                    user_location  \
# 533                Inspired People                        Australia
# 532                  Yhopix Rosete  City Of Maasin, Eastern Visayas
# 531               Phil News Agency                      Quezon City
# 530              Mohd Lateef Babla                            India
# 529    Eagle News British Columbia      Vancouver, British Columbia
# ...                            ...                              ...
# 26401                        Pavan                            India
# 24135                Marco Vergari                  Ravenna , Italy
# 27436          Celine Emma la Cour               København, Danmark
# 26057         🕷Financial Bear 3.5%             #KeepFightingMichael
# 23776                    bc Yume 📷                           東京都品川区
#
#                                         user_description         user_created  \
# ...

# %%
f_data.to_csv('complete dataset for vaccine_DecToMar.csv')

# %%
df.to_csv('raw_complete dataset for vaccine_DecToMar.csv')
